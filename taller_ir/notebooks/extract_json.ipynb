# %%
# !pip install PyMuPDF
# Out:
# Collecting PyMuPDF
#   Downloading pymupdf-1.26.4-cp39-abi3-manylinux_2_28_x86_64.whl.metadata (3.4 kB)
# Downloading pymupdf-1.26.4-cp39-abi3-manylinux_2_28_x86_64.whl (24.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.1/24.1 MB 39.2 MB/s eta 0:00:00
# Installing collected packages: PyMuPDF
# Successfully installed PyMuPDF-1.26.4

# %%
# !pip -q install -U "spacy==3.7.4"
# !python -m spacy download es_core_news_sm
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 1.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.5/6.5 MB 56.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.0/57.0 kB 4.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 865.0/865.0 kB 38.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 54.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 3.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.1/50.1 kB 3.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 30.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.0/45.0 kB 3.3 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gradio 5.44.1 requires typer<1.0,>=0.12; sys_platform != "emscripten", but you have typer 0.9.4 which is incompatible.
# opencv-python-headless 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# opencv-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# opencv-contrib-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# Collecting es-core-news-sm==3.7.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/es_core_news_sm-3.7.0/es_core_news_sm-3.7.0-py3-none-any.whl (12.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.9/12.9 MB 89.5 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.8.0,>=3.7.0 in /usr/local/lib/python3.12/dist-packages (from es-core-news-sm==3.7.0) (3.7.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.12/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.12/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (1.0.13)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.12/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (2.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.12/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (3.0.10)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.12/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.12/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.12/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (2.5.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.12/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /usr/local/lib/python3.12/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (0.9.4)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.12/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.12/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (4.67.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (2.32.4)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.12/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (2.11.7)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (3.1.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (75.2.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (25.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.12/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (3.5.0)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.12/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (1.26.4)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.12/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.12/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (0.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (2025.8.3)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.12/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (0.1.5)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.12/dist-packages (from typer<0.10.0,>=0.3.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (8.2.1)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from weasel<0.4.0,>=0.1.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (3.0.2)
# Requirement already satisfied: marisa-trie>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (1.3.1)
# Installing collected packages: es-core-news-sm
# Successfully installed es-core-news-sm-3.7.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('es_core_news_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
import pandas as pd
import json
import fitz
import re
import unicodedata
import spacy

# %% [markdown]
# # 1. Extracción y Preparación del Corpus:

# %% [markdown]
# ## 1.1. Extraer las entrevistas

# %%
# Cargar datos de los testimonios
with open('/content/entrevistas_all_2023-03-21_14-24_05.json', 'r') as file:
    data = json.load(file)
df_testimonios = pd.DataFrame(data)
df_testimonios.head(3)
# Out:
#                          id_doc  pages  \
# 0  5eb4e7bfda6da3b502da3589.pdf     30
# 1  5eb4e7c0da6da3b502da358e.pdf     30
# 2  5eb4e7c1da6da3b502da3593.pdf     15
#
#                                                 text
# 0  001-VI-00008\nTEST:  Bajo la apariencia de una...
# 1  001-VI-00008\nTEST:  Bajo la apariencia de una...
# 2  ENT:\nBueno, hoy es --------------------------...

# %%
df_testimonios.shape
# Out:
# (2486, 3)

# %%
# 1. Eliminar vacíos
vacios = df_testimonios["text"].eq("   ")
print(f"Entrevistas vacías detectadas: {vacios.sum()}")
df_testimonios = df_testimonios.loc[~vacios].reset_index(drop=True)
# Out:
# Entrevistas vacías detectadas: 2

# %%
# Contar duplicados en la columna 'text'
duplicados = df_testimonios["text"].duplicated().sum()
print(f"Se encontraron {duplicados} entrevistas duplicadas.")

# Eliminar duplicados
df_testimonios = df_testimonios.drop_duplicates(subset="text").reset_index(drop=True)
# Out:
# Se encontraron 268 entrevistas duplicadas.

# %%
df_testimonios.shape
# Out:
# (2216, 3)

# %% [markdown]
# ## 1.2. Limpieza preliminar de las entrevistas

# %%
def limpiar_texto(texto):

    # Normalizar unicode (acentos, espacios raros, símbolos)
    texto = unicodedata.normalize("NFKC", texto)

    texto = texto.lower()  # normalizamos todo a minúsculas

    # Eliminar encabezados tipo 001-VI-00008
    texto = re.sub(r"\b\d{2,5}-[a-z]{2,}-\d{3,}\b", " ", texto)

    # Eliminar paréntesis con números tipo _(868)
    texto = re.sub(r"_\(\d+\)", " ", texto)

    # Eliminar marcas de tiempo tipo 01:30:51 o 00:08–00:48
    texto = re.sub(r"\d{1,2}:\d{2}(:\d{2})?", " ", texto)
    texto = re.sub(r"\d{1,2}:\d{2}[–-]\d{1,2}:\d{2}", " ", texto)

    # Buscar intervenciones de TEST/TEST1/TEST 2... hasta ENT
    fragmentos = re.findall(r"test\s*\d*:(.*?)(?=ent\s*\d*:|ent:|$)", texto, flags=re.S | re.I)

    if fragmentos:
        texto = " ".join(fragmentos)
    else:
        # fallback: usar texto completo (ya en minúscula)
        texto = texto

    # Eliminar etiquetas entre corchetes [....]
    texto = re.sub(r"\[.*?\]", " ", texto)

    # Eliminar guiones largos
    texto = re.sub(r"-{2,}", " ", texto)

    # Quitar números pegados a palabras tipo "familiar1" → "familiar"
    texto = re.sub(r"\b([a-záéíóúñü]+)\d+\b", r"\1", texto)

    # Separar números de palabras pegadas: 2personas → 2 personas
    texto = re.sub(r"(\d+)([a-záéíóúñü]+)", r"\1 \2", texto)

    # Quitar caracteres no alfanuméricos
    texto = re.sub(r"[^a-záéíóúñü0-9\s]", " ", texto)

    # Normalizar espacios
    texto = re.sub(r"\s+", " ", texto).strip()

    return texto

# Aplicar al dataframe
df_testimonios["text_clean"] = df_testimonios["text"].apply(limpiar_texto)

# %% [markdown]
# ## 1.3. Tokenizacion y eliminacion de stopwords

# %%
# Tokenizacion y eliminacion de stopwords

# Cargar modelo de spaCy en español
nlp = spacy.load("es_core_news_sm")

def tokenizar(texto):
    doc = nlp(texto)
    # Tokens con stopwords (y sin puntuación)
    tokens_all = [tok.text for tok in doc if not tok.is_punct]
    # Tokens sin stopwords ni puntuación
    tokens_no_stop = [tok.text for tok in doc if not tok.is_stop and not tok.is_punct]
    return tokens_all, tokens_no_stop

# Aplicar al corpus
df_testimonios[["tokens_all", "tokens_no_stop"]] = df_testimonios["text_clean"].apply(
    lambda x: pd.Series(tokenizar(x))
)

# Ejemplo
print(df_testimonios[["text_clean", "tokens_all", "tokens_no_stop"]].head(1).to_string())
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# 0  bajo la apariencia de una democracia formal en colombia se vivía un régimen de terror servicios de inteligencia estatales estamos hablando ya a partir de 1985 entonces te decía que servicios de inteligencia oficiales estructuras de las fuerzas militares y de policía y del organización pública 1 se entrelazaban con grupos paramilitares de extrema derecha en desarrollo de una estrategia de contrainsurgencia aparejada con una guerra sucia de liquidación y exterminio del movimiento popular colombiano del que fueron víctimas opositores políticos sociales y de consciencia miles de campesinos de las regiones agrarias bajo la influencia del movimiento guerrillero miles de sindicalistas además de defensores de derechos humanos de jueces de la república que se atrevieron a investigar los crímenes de esa guerra sucia y en ese contexto el genocidio perpetrado contra la unión patriótica a quien le asesinaron sus 2 candidatos a la presidencia de la república jaime pardo leal y bernardo jaramillo los dos juristas que además habían sido presidentes nacionales de la unión patriótica en una guerra sucia con evidentes connotaciones de terrorismo de estado por la participación inocultable de agentes estatales en la perpetración de los crímenes el caso de jaime pardo que es suficientemente conocido quien aparece como autor material se estableció procesalmente que realizó más de 20 llamadas el día anterior al asesinato a los servicios de inteligencia de la unidad militar del ejército en en el caso de bernardo jaramillo ossa que fue asesinado en el aeropuerto el dorado de bogotá y que por cierto en ese atentado resultó igualmente lesionado el doctor ernesto samper pizano que fue luego presidente de la república en el caso de bernardo aparecen pagos efectuados por el organización pública 1 cuantiosos pagos hechos al hermano de responsable 1 que fue el autor material del crimen de bernardo jaramillo y a su señora madre eso fue establecido a plenitud por la fiscalía de manera que después del crimen esto fue más o menos 1 año después el asesinato de bernardo recién que fue también asesinado el autor material el responsible 1 entonces el organización pública 1 aparece haciendo pagos de dineros donaciones cuantiosas al hermano y a la señora madre es decir que la participación de agentes estatales en los crímenes para citar apenas ese ejemplo es verdaderamente inocultable perdóname si quieres apaga quisiera agregarle igualmente que el genocidio del que fue víctima la unión patriótica exterminada mediante el crimen sistemático perpetrado contra sus militantes en un escenario de impunidad absoluta de los determinadores y los perpetradores amparados por fueros especiales un escenario desprovisto de derechos fundamentales signado por el militarismo por la barbarie paramilitar al servicio del terrorismo de estado por el otorgamiento excluyente de las oportunidades a un grupo reducido de la sociedad la unión patriótica surgió en el contexto de los diálogos de paz entre el presidente belisario betancur y los destacamentos guerrilleros de las farc enarbolando las banderas de la salida política negociada del conflicto interno y la solución progresista de la crisis social contenida en la confrontación armada entrañablemente unida a lo más radical y más generoso de las luchas del pueblo colombiano la unión patriótica se planteó contener exaltar y sobrepasar las más elevadas y profundas aspiraciones de todos los demócratas de toda la gente que en colombia anhelaba que la paz fuera un hechos irreversible en nuestro país esos ideales desgraciadamente fueron ahogados en sangre por eso yo podría decir que la historia de la unión patriótica es la historia de una esperanza masacrada el genocidio de la unión patriótica de otra parte significó el exterminio de una opción de poder popular evidentemente en la primera elección en que participa la unión patriótica en 1986 se convirtió en la tercera fuerza política electoral del país y evidenció su vocación de alternativa de po ...

# %% [markdown]
# ## 1.4. Lematizacion

# %%
from google.colab import files

def lematizar(texto):
    doc = nlp(texto)
    # Lemas con stopwords (sin puntuación)
    lemmas_all = [tok.lemma_ for tok in doc if not tok.is_punct]
    # Lemas sin stopwords ni puntuación
    lemmas_no_stop = [tok.lemma_ for tok in doc if not tok.is_stop and not tok.is_punct]
    return lemmas_all, lemmas_no_stop

# Aplicar al corpus
df_testimonios[["lemmas_all", "lemmas_no_stop"]] = df_testimonios["text_clean"].apply(
    lambda x: pd.Series(lematizar(x))
)

# Ejemplo
print(df_testimonios[["tokens_all", "tokens_no_stop", "lemmas_all", "lemmas_no_stop"]].head(1).to_string())

# Guardar a CSV
output_file = "testimonios_procesados.csv"
df_testimonios.to_csv(output_file, index=False, encoding="utf-8")

# Descargar automáticamente al PC
files.download(output_file)
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    tokens_all                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            tokens_no_stop                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             lemmas_all                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     lemmas_no_stop
# 0  [bajo, la, apariencia, de, una, democracia, formal, en, colombia, se, vivía, un, régimen, de, terror, servicios, de, inteligencia, estatales, estamos, hablando, ya, a, partir, de, 1985, entonces, te, decía, que, servicios, de, inteligencia, oficiales, estructuras, de, las, fuerzas, militares, y, de, policía, y, del, organización, pública, 1, se, entrelazaban, con, grupos, paramilitares, de, extrema, derecha, en, desarrollo, de, una, estrategia, de, contrainsurgencia, aparejada, con, una, guerra, sucia, de, liquidación, y, exterminio, del, movimiento, popular, colombiano, del, que, fueron, víctimas, opositores, políticos, sociales, y, de, consciencia, miles, de, campesinos, de, las, regiones, agrarias, bajo, la, influencia, del, movimiento, guerrillero, miles, de, ...]  [apariencia, democracia, formal, colombia, vivía, régimen, terror, servicios, inteligencia, estatales, hablando, 1985, decía, servicios, inteligencia, oficiales, estructuras, fuerzas, militares, policía, organización, pública, 1, entrelazaban, grupos, paramilitares, extrema, derecha, desarrollo, estrategia, contrainsurgencia, aparejada, guerra, sucia, liquidación, exterminio, movimiento, popular, colombiano, víctimas, opositores, políticos, sociales, consciencia, miles, campesinos, regiones, agrarias, influencia, movimiento, guerrillero, miles, sindicalistas, defensores, derechos, humanos, jueces, república, atrevieron, investigar, crímenes, guerra, sucia, contexto, genocidio, perpetrado, unión, patriótica, asesinaron, 2, candidatos, presidencia, república, jaime, pardo, leal, bernardo, jaramillo, juristas, presidentes, nacionales, unión, patriótica, guerra, sucia, evidentes, connotaciones, terrorismo, participación, inocultable, agentes, estatales, perpetración, crímenes, caso, jaime, pardo, suficientemente, conocido, aparece, ...]  [bajo, el, apariencia, de, uno, democracia, formal, en, colombia, él, vivir, uno, régimen, de, terror, servicio, de, inteligencia, estatal, estar, hablar, ya, a, partir, de, 1985, entonces, tú, decir, que, servicio, de, inteligencia, oficial, estructura, de, el, fuerza, militar, y, de, policía, y, del, organización, público, 1, él, entrelazar, con, grupo, paramilitar, de, extremo, derecha, en, desarrollo, de, uno, estrategia, de, contrainsurgencia, aparejado, con, uno, guerra, sucio, de, liquidación, y, exterminio, del, movimiento, popular, colombiano, del, que, ser, víctima, opositor, político, social, y, de, consciencia, mil, de, campesino, de, el, región, agrario, bajo, el, influencia, del, movimiento, guerrillero, mil, de, ...]  [apariencia, democracia, formal, colombia, vivir, régimen, terror, servicio, inteligencia, estatal, hablar, 1985, decir, servicio, inteligencia, oficial, estructura, fuerza, militar, policía, organización, público, 1, entrelazar, grupo, paramilitar, extremo, derecha, desarrollo, estrategia, contrainsurgencia, aparejado, guerra, sucio, liquidación, exterminio, movimiento, popular, colombiano, víctima, opositor, político, social, consciencia, mil, campesino, región, agrario, influencia, movimiento, guerrillero, mil, sindicalista, defensor, derechos, humanos, juez, república, atreveír, investigar, crimen, guerra, sucio, contexto, genocidio, perpetrado, unión, patriótico, asesinar, 2, candidato, presidencia, república, jaime, pardo, leal, bernardo, jaramillo, jurista, president, nacional, unión, patriótico, guerra, sucio, evidente, connotación, terrorismo, participación, inocultable, agente, estatal, perpetración, crimen, caso, jaime, pardo, suficientemente, conocido, aparecer, ...]

# %% [markdown]
# ## 1.5. Limpieza post

# %%
# Función para limpiar tokens o lemmas (listas)
def limpiar_tokens(lista):
    if not isinstance(lista, list):
        return []
    return [tok for tok in lista if not re.fullmatch(r"(test|ent)\d*", tok)]

# Función para limpiar texto plano
def limpiar_texto_extra(texto):
    if not isinstance(texto, str):
        return ""
    return re.sub(r"\b(test|ent)\d*\b", "", texto).strip()

# Aplicar sobre tokens y lemmas
df_testimonios["tokens_all"]     = df_testimonios["tokens_all"].apply(limpiar_tokens)
df_testimonios["tokens_no_stop"] = df_testimonios["tokens_no_stop"].apply(limpiar_tokens)
df_testimonios["lemmas_all"]     = df_testimonios["lemmas_all"].apply(limpiar_tokens)
df_testimonios["lemmas_no_stop"] = df_testimonios["lemmas_no_stop"].apply(limpiar_tokens)

# Aplicar sobre texto plano
df_testimonios["text_clean"] = df_testimonios["text_clean"].apply(limpiar_texto_extra)

# Normalizar espacios otra vez (pueden quedar dobles tras quitar palabras)
df_testimonios["text_clean"] = df_testimonios["text_clean"].str.replace(r"\s+", " ", regex=True).str.strip()

# %%
df_testimonios
# Out:
#                             id_doc  pages  \
# 0     5eb4e7bfda6da3b502da3589.pdf     30
# 1     5eb4e7c1da6da3b502da3593.pdf     15
# 2     5eb4e7c1da6da3b502da3595.pdf     38
# 3     5eb4e7c1da6da3b502da3599.pdf     24
# 4     5eb4e7c2da6da3b502da359d.pdf     17
# ...                            ...    ...
# 2211  625f3e67755cba02e57a5ee7.pdf     41
# 2212  625fd7b8755cba02e5b68d8f.pdf     19
# 2213  62625339755cba02e5158c7a.pdf     13
# 2214  6268621d8293e58b8f480f09.pdf     49
# 2215  62a0bbc2206f25fb6b33c3fb.pdf     17
#
#                                                    text  \
# 0     001-VI-00008\nTEST:  Bajo la apariencia de una...
# 1     ENT:\nBueno, hoy es --------------------------...
# 2     001-VI-00011\n \n001-VI-00011_(48057):  01:30:...
# 3     ENT: Pues buenas tardes TEST Le damos la bienv...
# 4     AUDIO 001-VI-00015_ (48157)\nENT: Bueno, pues ...
# ...                                                 ...
# 2211  ENT: Con estocomienzo la entrevista a TEST Mi ...
# 2212  ENT: Bueno. -------días don TEST… TEST [INTERR...
# 2213  ENT: Bueno TEST, mi corazón,entonces ahora vam...
# 2214  077-VI-00013_ (34120)\nENT: --- de --------- d...
# 2215  ENT: Hoy -------- se da inicio a entrevista in...
#
#                                              text_clean  \
# 0     bajo la apariencia de una democracia formal en...
# 1     sí con mucho gusto mi nombre es nací en en est...
# 2     buenas tardes gracias con mucho gusto con much...
# 3     gracias entonces bueno buenas tardes muchas gr...
# 4     ok buenos días y muchísimas gracias por el esp...
# ...                                                 ...
# 2211  bueno mi nombre es como usted lo ha dicho naci...
# 2212  judiciales judiciales si bueno eehm yo empiezo...
# 2213  bueno luego qué pasa que eso me dañó la vida t...
# 2214  pues yo considero que la idea la idea es habla...
# 2215  así como le digo desde ahí tonces el alcalde n...
#
#                                              tokens_all  \
# 0     [bajo, la, apariencia, de, una, democracia, fo...
# 1     [sí, con, mucho, gusto, mi, nombre, es, nací, ...
# 2     [buenas, tardes, gracias, con, mucho, gusto, c...
# 3     [gracias, entonces, bueno, buenas, tardes, muc...
# 4     [ok, buenos, días, y, muchísimas, gracias, por...
# ...                                                 ...
# 2211  [bueno, mi, nombre, es, como, usted, lo, ha, d...
# 2212  [judiciales, judiciales, si, bueno, eehm, yo, ...
# 2213  [bueno, luego, qué, pasa, que, eso, me, dañó, ...
# 2214  [pues, yo, considero, que, la, idea, la, idea,...
# 2215  [así, como, le, digo, desde, ahí, tonces, el, ...
#
#                                          tokens_no_stop  \
# 0     [apariencia, democracia, formal, colombia, viv...
# 1     [gusto, nombre, nací, estudié, colegios, colom...
# 2     [tardes, gracias, gusto, gusto, nombre, inicio...
# 3     [gracias, tardes, gracias, espacio, llamo, pap...
# 4     [ok, muchísimas, gracias, espacio, ok, llego, ...
# ...                                                 ...
# 2211  [nombre, nacida, arauca, hija, familar, 1, fam...
# 2212  [judiciales, judiciales, eehm, empiezo, acá, t...
# 2213  [pasa, dañó, vida, amiga, conocida, compañera,...
# 2214  [considero, idea, idea, hablar, sepa, relación...
# 2215  [digo, tonces, alcalde, puso, colegio, allá, p...
#
#                                              lemmas_all  \
# 0     [bajo, el, apariencia, de, uno, democracia, fo...
# 1     [él, con, mucho, gusto, mi, nombre, ser, nací,...
# 2     [buena, tarde, gracias, con, mucho, gusto, con...
# 3     [gracias, entonces, bueno, buena, tarde, mucho...
# 4     [ok, buen, día, y, muchísimar, gracia, por, el...
# ...                                                 ...
# 2211  [bueno, mi, nombre, ser, como, usted, él, habe...
# 2212  [judicial, judicial, si, bueno, eehm, yo, empi...
# 2213  [bueno, luego, qué, pasar, que, ese, yo, dañar...
# 2214  [pues, yo, considerar, que, el, idea, el, idea...
# 2215  [así, como, él, decir, desde, ahí, tonz, el, a...
#
#                                          lemmas_no_stop
# 0     [apariencia, democracia, formal, colombia, viv...
# 1     [gusto, nombre, nací, estudié, colegio, colomb...
# 2     [tarde, gracias, gusto, gusto, nombre, inicio,...
# 3     [gracias, tarde, gracia, espacio, llamar, papá...
# 4     [ok, muchísimar, gracia, espacio, ok, llego, r...
# ...                                                 ...
# 2211  [nombre, nacido, arauca, hija, familar, 1, fam...
# 2212  [judicial, judicial, eehm, empiezo, acá, traba...
# 2213  [pasar, dañar, vida, amiga, conocer, compañera...
# 2214  [considerar, idea, idea, hablar, separ, relaci...
# 2215  [decir, tonz, alcalde, poner, colegio, allá, p...
#
# [2216 rows x 8 columns]

# %%
# Guardar a CSV
output_file = "entrevistas_procesadas.csv"
df_testimonios.to_csv(output_file, index=False, encoding="utf-8")
